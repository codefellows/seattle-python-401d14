# %%
# imports
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
salary = pd.read_csv("./salary_plus_snacks.csv")
salary.head()
# Out:
#    YearsExperience  Salary  Snacks
# 0             13.5  139465      13
# 1             12.9  135675      13
# 2             12.3  128765      12
# 3             11.2  127345      12
# 4             11.5  126756      12

# %%
# select features
X = salary["Snacks"].values
y = salary["Salary"].values
X
# Out:
# array([13, 13, 12, 12, 12, 12, 12, 11, 11, 11, 10, 10, 10,  9,  9,  8,  8,
#         8,  6,  6,  6,  6,  6,  6,  5,  5,  5,  5,  5,  5,  4,  4,  3,  3,
#         3])

# %%
y
# Out:
# array([139465, 135675, 128765, 127345, 126756, 122391, 121872, 116969,
#        113812, 112635, 109431, 105582, 101302,  98273,  93940,  91738,
#         83088,  81363,  67938,  66029,  64445,  63218,  61111,  60150,
#         57189,  57081,  56957,  56642,  55794,  54445,  46205,  43525,
#         39891,  39343,  37731])

# %%
X = X.reshape(-1,1)

# %%
X
# Out:
# array([[13],
#        [13],
#        [12],
#        [12],
#        [12],
#        [12],
#        [12],
#        [11],
#        [11],
#        [11],
#        [10],
#        [10],
#        [10],
#        [ 9],
#        [ 9],
#        [ 8],
#        [ 8],
#        [ 8],
#        [ 6],
#        [ 6],
#        [ 6],
#        [ 6],
#        [ 6],
#        [ 6],
#        [ 5],
#        [ 5],
#        [ 5],
#        [ 5],
#        [ 5],
#        [ 5],
#        [ 4],
#        [ 4],
#        [ 3],
#        [ 3],
#        [ 3]])

# %%
# X feature = Years of Experience
# y = salary in $
x_train, x_test, y_train, y_test = train_test_split(X, y, train_size=0.8, test_size=0.2, random_state=100)
print(f"X_train shape {x_train.shape}")
print(f"y_train shape {y_train.shape}")
print(f"X_test shap {x_test.shape}")
print(f"y_test shape {y_test.shape}")
# Out:
# X_train shape (28, 1)
# y_train shape (28,)
# X_test shap (7, 1)
# y_test shape (7,)

# %%
# %matplotlib inline
plt.scatter(x_train, y_train,color='red')
# plt.xlabel('Years of Experience')
plt.xlabel('Snacks per day')
plt.ylabel('Salary in $')
plt.title('Training data')
plt.show()

# %%
lm = LinearRegression()
lm.fit(x_train, y_train)
y_predict = lm.predict(x_test)
print(f"Train accuracy {round(lm.score(x_train,y_train)*100,2)} %")
print(f"Test accuracy {round(lm.score(x_test,y_test)*100,2)} %")
# Out:
# Train accuracy 99.03 %
# Test accuracy 99.52 %

# %%
plt.scatter(x_train,y_train,color='red')
plt.plot(x_test,y_predict)
plt.xlabel("Years of Experience")
plt.ylabel("Salary in $")
plt.title("Trained model plot")
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args, scalex=True, scaley=True, data=None, **kwargs)>

# %%
import seaborn as sns

# %%
salary_seaborn = pd.read_csv("./salary_plus_snacks.csv")

# %%
sns.set()
plt.figure(figsize=(10,6),dpi=300)
sns.regplot(x='YearsExperience', y='Salary', data=salary_seaborn)

# %%
sns.set()
plt.figure(figsize=(10,6),dpi=300)
sns.regplot(x='Snacks', y='Salary', data=salary_seaborn)

# %% [markdown]
# ## Anscome Quartet

# %%
anscombe = sns.load_dataset("anscombe")
sns.regplot(x='x',y='y', data=anscombe.query("dataset == 'II'"), order=2)

# %%
sns.lmplot(x="x", y="y", data=anscombe.query("dataset == 'III'"),
           robust=True, ci=None, scatter_kws={"s": 80})
